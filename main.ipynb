# %%
# !pip install np ultralytics opencv-python pygame sort-track
# Out:
# Requirement already satisfied: sort-track in ./venv/lib/python3.11/site-packages (0.0.8)
# Requirement already satisfied: filterpy==1.4.5 in ./venv/lib/python3.11/site-packages (from sort-track) (1.4.5)
# Requirement already satisfied: scipy==1.9.3 in ./venv/lib/python3.11/site-packages (from sort-track) (1.9.3)
# Requirement already satisfied: numpy in ./venv/lib/python3.11/site-packages (from filterpy==1.4.5->sort-track) (1.25.2)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.11/site-packages (from filterpy==1.4.5->sort-track) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->sort-track) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->sort-track) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->sort-track) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->sort-track) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->sort-track) (25.0)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->sort-track) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in ./venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->sort-track) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.11/site-packages (from matplotlib->filterpy==1.4.5->sort-track) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->filterpy==1.4.5->sort-track) (1.17.0)

# %%
import cv2
from ultralytics import YOLO
import time
import numpy as np               
from sort.tracker import SortTracker
import pygame
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.14)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
print("Loading YOLOv8 model...")
model = YOLO('yolov8n.pt')
print("Model loaded.")
# Out:
# Loading YOLOv8 model...
# Model loaded.

# %%
car_tracker = SortTracker(max_age=20, min_hits=3, iou_threshold=0.3)
person_tracker = SortTracker(max_age=20, min_hits=3, iou_threshold=0.3)

# Directional Audio Initialize
try:
    pygame.mixer.init(frequency=22050, size=-16, channels=2, buffer=4096)
    alert_sound = pygame.mixer.Sound('danger.mp3') 
    print("Audio engine initialized.")
except pygame.error as e:
    print(f"Error initializing audio or loading file: {e}")
    print("### PLEASE MAKE SURE 'danger_alert.wav' IS IN THE FOLDER ###")
    alert_sound = None
# Out:
# Audio engine initialized.

# %%
video_path = 'sample.mp4' 
cap = cv2.VideoCapture(video_path)

# %%
def play_panned_alert(car_center_x, frame_width):
    """Plays the alert sound, panned left or right."""
    if not alert_sound:
        print("Audio file not loaded. Cannot play alert.")
        return
        
    # Calculate pan: 0.0 = full left, 1.0 = full right
    pan = max(0.0, min(1.0, car_center_x / frame_width))
    
    left_volume = 1.0 - pan
    right_volume = pan
    
    try:
        channel = pygame.mixer.find_channel(True) 
        channel.set_volume(left_volume, right_volume)
        channel.play(alert_sound)
    except Exception as e:
        print(f"Error playing sound: {e}")

# %%
last_car_areas = {} 
alert_cooldown = 3  
last_alert_time = 0

DANGER_SPEED_THRESHOLD = 500
PATH_DANGER_THRESHOLD = 250   
CLOSE_THRESHOLD = 35000

# %%
while cap.isOpened():
    success, frame = cap.read()
    if not success:
        print("Video finished or failed to read a frame.")
        break

    # Get frame dimensions for audio panning
    frame_height, frame_width, _ = frame.shape

    results = model(frame)

    person_detections = [] 
    car_detections = []    

    for box in results[0].boxes:
        conf = float(box.conf[0])
        if conf < 0.4: 
            continue
            
        cls_id = int(box.cls[0])
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        
        detection_data = [x1, y1, x2, y2, conf, cls_id] 
        
        if cls_id == 0: # Person
            person_detections.append(detection_data)
        elif cls_id == 2 or cls_id == 7: # Car or Truck
            car_detections.append(detection_data)

    if len(person_detections) > 0:
        persons_to_track = np.array(person_detections)
    else:
        persons_to_track = np.empty((0, 6))

    if len(car_detections) > 0:
        cars_to_track = np.array(car_detections)
    else:
        cars_to_track = np.empty((0, 6))

    tracked_persons = person_tracker.update(persons_to_track, frame)
    tracked_cars = car_tracker.update(cars_to_track, frame)
    is_danger_present = False
    danger_car_center_x = 0 
    current_car_areas = {}  
    speed_rate_display = 0  

    for person in tracked_persons:
        person_x1 = int(person[0])
        person_y1 = int(person[1])
        person_x2 = int(person[2])
        person_y2 = int(person[3])
        person_id = int(person[-1]) 
        
        person_center_x = (person_x1 + person_x2) / 2
        
        for car in tracked_cars:
            car_x1 = int(car[0])
            car_y1 = int(car[1])
            car_x2 = int(car[2])
            car_y2 = int(car[3])
            car_id = int(car[-1]) 
            
            car_center_x = (car_x1 + car_x2) / 2
            current_car_area = (car_x2 - car_x1) * (car_y2 - car_y1)
            
            current_car_areas[car_id] = current_car_area
            
            is_dangerously_fast = False
            
            if car_id in last_car_areas:
                speed_rate = current_car_area - last_car_areas[car_id]
                speed_rate_display = speed_rate 
                if speed_rate > DANGER_SPEED_THRESHOLD:
                    is_dangerously_fast = True
            
            path_danger = abs(person_center_x - car_center_x) < PATH_DANGER_THRESHOLD
            
            is_close = current_car_area > CLOSE_THRESHOLD

            if is_dangerously_fast and path_danger and is_close:
                is_danger_present = True
                danger_car_center_x = car_center_x 
                
                
                break 
        if is_danger_present:
            break 

    last_car_areas = current_car_areas.copy()

    annotated_frame = results[0].plot() 
    
    if is_danger_present:
        cv2.putText(
            annotated_frame, 
            "DANGER! COLLISION IMMINENT!", 
            (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 
            2, (0, 0, 255), 3, cv2.LINE_AA
        )
        
        current_time = time.time()
        if (current_time - last_alert_time) > alert_cooldown:
            if not pygame.mixer.get_busy():
                print(f"DANGER! Panning audio based on X-coord: {danger_car_center_x}")
                last_alert_time = current_time
                play_panned_alert(danger_car_center_x, frame_width)

    cv2.putText(
        annotated_frame, 
        f"Speed Rate: {int(speed_rate_display)}", 
        (50, 150), cv2.FONT_HERSHEY_SIMPLEX, 
        1, (0, 255, 0), 2, cv2.LINE_AA
    )
    
    cv2.imshow("YOLOv8 Danger Detection", annotated_frame)

    # press q to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("'q' key pressed. Exiting...")
        break
# Out:
# 0: 640x512 2 persons, 3 cars, 2 motorcycles, 1 truck, 1 bed, 145.0ms
# Speed: 5.1ms preprocess, 145.0ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 4 cars, 1 motorcycle, 1 truck, 1 bed, 14.9ms
# Speed: 7.4ms preprocess, 14.9ms inference, 9.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 3 cars, 1 motorcycle, 1 bed, 15.7ms
# Speed: 4.4ms preprocess, 15.7ms inference, 8.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 3 motorcycles, 1 bed, 11.6ms
# Speed: 4.8ms preprocess, 11.6ms inference, 8.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 3 motorcycles, 1 truck, 1 bed, 12.1ms
# Speed: 3.8ms preprocess, 12.1ms inference, 9.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 3 motorcycles, 1 bed, 13.8ms
# Speed: 5.2ms preprocess, 13.8ms inference, 9.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 3 motorcycles, 1 bed, 11.6ms
# Speed: 4.1ms preprocess, 11.6ms inference, 9.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 3 motorcycles, 1 bed, 14.0ms
# Speed: 5.4ms preprocess, 14.0ms inference, 9.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 3 cars, 3 motorcycles, 1 bed, 12.9ms
# Speed: 3.9ms preprocess, 12.9ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 persons, 4 cars, 3 motorcycles, 1 truck, 1 bed, 13.7ms
# Speed: 4.7ms preprocess, 13.7ms inference, 12.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 persons, 4 cars, 3 motorcycles, 1 truck, 1 bed, 16.1ms
# Speed: 6.5ms preprocess, 16.1ms inference, 17.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 4 motorcycles, 1 truck, 1 bed, 12.6ms
# Speed: 6.6ms preprocess, 12.6ms inference, 12.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 4 motorcycles, 1 truck, 1 bed, 12.1ms
# Speed: 4.1ms preprocess, 12.1ms inference, 9.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 2 cars, 5 motorcycles, 1 truck, 1 bed, 12.7ms
# Speed: 3.9ms preprocess, 12.7ms inference, 10.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 4 cars, 4 motorcycles, 1 truck, 1 bed, 11.9ms
# Speed: 4.5ms preprocess, 11.9ms inference, 12.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars,
0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 13.4ms
# Speed: 4.0ms preprocess, 13.4ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 13.9ms
# Speed: 3.7ms preprocess, 13.9ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.9ms
# Speed: 4.3ms preprocess, 11.9ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.2ms
# Speed: 3.9ms preprocess, 11.2ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 12.4ms
# Speed: 4.5ms preprocess, 12.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 13.0ms
# Speed: 4.8ms preprocess, 13.0ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 15.5ms
# Speed: 6.3ms preprocess, 15.5ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 15.0ms
# Speed: 5.3ms preprocess, 15.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 trucks, 13.0ms
# Speed: 5.7ms preprocess, 13.0ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 truck, 13.6ms
# Speed: 4.4ms preprocess, 13.6ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 2 trucks, 11.9ms
# Speed: 5.9ms preprocess, 11.9ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 1 car, 2 trucks, 15.9ms
# Speed: 6.9ms preprocess, 15.9ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 persons, 3 cars, 2 trucks, 17.1ms
# Speed: 6.0ms preprocess, 17.1ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 truck, 11.2ms
# Speed: 6.0ms preprocess, 11.2ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 1 truck, 13.2ms
# Speed: 4.8ms preprocess, 13.2ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 2 trucks, 12.6ms
# Speed: 5.1ms preprocess, 12.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 14.1ms
# Speed: 3.9ms preprocess, 14.1ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.4ms
# Speed: 3.9ms preprocess, 11.4ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 13.9ms
# Speed: 4.2ms preprocess, 13.9ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 14.9ms
# Speed: 4.0ms preprocess, 14.9ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 11.9ms
# Speed: 3.9ms preprocess, 11.9ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 13.1ms
# Speed: 5.3ms preprocess, 13.1ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 14.1ms
# Speed: 4.6ms preprocess, 14.1ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 trucks, 13.0ms
# Speed: 3.7ms preprocess, 13.0ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 14.7ms
# Speed: 5.5ms preprocess, 14.7ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 14.5ms
# Speed: 5.8ms preprocess, 14.5ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 14.5ms
# Speed: 5.3ms preprocess, 14.5ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 14.8ms
# Speed: 5.4ms preprocess, 14.8ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 trucks, 12.0ms
# Speed: 3.7ms preprocess, 12.0ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 12.5ms
# Speed: 3.8ms preprocess, 12.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 motorcycle, 1 truck, 11.6ms
# Speed: 4.0ms preprocess, 11.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 truck, 12.2ms
# Speed: 4.3ms preprocess, 12.2ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 truck, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 truck, 12.6ms
# Speed: 4.5ms preprocess, 12.6ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 1 motorcycle, 12.9ms
# Speed: 3.8ms preprocess, 12.9ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 1 truck, 13.7ms
# Speed: 5.1ms preprocess, 13.7ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 13.6ms
# Speed: 5.8ms preprocess, 13.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 13.3ms
# Speed: 5.1ms preprocess, 13.3ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 truck, 13.4ms
# Speed: 5.0ms preprocess, 13.4ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 2 trucks, 13.9ms
# Speed: 5.2ms preprocess, 13.9ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 truck, 14.5ms
# Speed: 5.1ms preprocess, 14.5ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 truck, 14.5ms
# Speed: 5.4ms preprocess, 14.5ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 13.4ms
# Speed: 4.2ms preprocess, 13.4ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 1 truck, 13.6ms
# Speed: 5.1ms preprocess, 13.6ms inference, 8.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 1 truck, 13.3ms
# Speed: 5.0ms preprocess, 13.3ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 5 cars, 2 motorcycles, 1 truck, 13.0ms
# Speed: 3.6ms preprocess, 13.0ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 truck, 11.1ms
# Speed: 3.8ms preprocess, 11.1ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 1 truck, 11.8ms
# Speed: 3.5ms preprocess, 11.8ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 3 cars, 1 airplane, 1 truck, 12.8ms
# Speed: 3.9ms preprocess, 12.8ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 1 truck, 13.9ms
# Speed: 3.6ms preprocess, 13.9ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 512)
# Video finished or failed to read a frame.

# %%
print("Cleaning up resources...")
cap.release()
cv2.destroyAllWindows()
pygame.mixer.quit() 
print("Script finished.")
# Out:
# Cleaning up resources...
# Script finished.

# %%
# import pyttsx3

# print("Initializing TTS engine...")
# try:
#     engine = pyttsx3.init()
# except Exception as e:
#     print(f"Error initializing engine: {e}")
#     exit()

# print("Engine initialized.")

# engine.setProperty('rate', 150)  # Speed of speech
# engine.setProperty('volume', 1.0) 

# print("Attempting to speak...")
# engine.say("Hello, this is a sound test. Can you hear me?")

# try:
#     engine.runAndWait()
#     print("Speech finished.")
# except Exception as e:
#     print(f"Error during runAndWait: {e}")

# print("Test complete.")
