# %%
# !pip install ultralytics opencv-python pyttsx3

# %%
import cv2
from ultralytics import YOLO
import pyttsx3
import threading
import time

# %%
print("Loading YOLOv8 model...")
# Load the YOLOv8 'nano' model because it's the fastest
model = YOLO('yolov8n.pt')
print("Model loaded.")

print("Initializing Text-to-Speech engine...")
# Initialize the Text-to-Speech (TTS) engine
tts_engine = pyttsx3.init()
print("TTS engine ready.")
# Out:
# Loading YOLOv8 model...
# Model loaded.
# Initializing Text-to-Speech engine...
# TTS engine ready.

# %%
video_path = 'sample.mp4'
cap = cv2.VideoCapture(video_path)

# %%
def say_alert(text_to_say):
    """Function to say text and manage speaking state."""
    global is_speaking 
    try:
        tts_engine.say(text_to_say)
        tts_engine.runAndWait()
        tts_engine.setProperty('rate', 500)
        tts_engine.setProperty('volumne', 1.0)

    except Exception as e:
        print(f"Error in TTS: {e}")
    finally:
        is_speaking = False

# %%
last_car_area = 0
alert_cooldown = 1  
last_alert_time = 0
is_speaking = False

# %%
while cap.isOpened():
    success, frame = cap.read()

    if not success:
        print("Video finished or failed to read a frame.")
        break

    results = model(frame)

    annotated_frame = results[0].plot()

    person_boxes = []
    car_boxes = []

    for box in results[0].boxes:
        class_id = int(box.cls)
        if class_id == 0: #Person in COCO dataset
            person_boxes.append(box)
        elif class_id == 2: # Car in COCO dataset
            car_boxes.append(box)
        elif class_id == 7: #Truck in COCO dataset
            car_boxes.append(box)

    is_danger = False

    # Check for danger only if both a person and a car are detected
    if person_boxes and car_boxes:
        # For simplicity, we'll focus on the first detected person and car
        person_box = person_boxes[0].xyxy[0]  # Coordinates [x1, y1, x2, y2]
        car_box = car_boxes[0].xyxy[0]

        person_center_x = (person_box[0] + person_box[2]) / 2
        car_center_x = (car_box[0] + car_box[2]) / 2
        current_car_area = (car_box[2] - car_box[0]) * (car_box[3] - car_box[1])

 
        is_incoming = current_car_area > (last_car_area * 1.10)  #10% buffer for noise

        path_danger = abs(person_center_x - car_center_x) < 200 

        is_close = current_car_area > 35000 

        if is_incoming and path_danger and is_close:
            is_danger = True

        last_car_area = current_car_area
    else:
        last_car_area = 0

    if is_danger:
        cv2.putText(
            annotated_frame, 
            "DANGER! COLLISION IMMINENT!", 
            (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 
            2, (0, 0, 255), 3, cv2.LINE_AA
        )
        
        current_time = time.time()
        
        if (current_time - last_alert_time) > alert_cooldown and not is_speaking:
            
            is_speaking = True
            
            print("DANGER DETECTED! Triggering voice alert.")
            last_alert_time = current_time
            
            threading.Thread(
                target=say_alert, 
                args=("Collision Imminent!",),
                daemon=True
            ).start()

    cv2.imshow("YOLOv8 Danger Detection", annotated_frame)


    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("'q' key pressed. Exiting...")
        break
# Out:
# 0: 640x512 2 persons, 3 cars, 2 motorcycles, 1 truck, 1 bed, 121.4ms
# Speed: 5.6ms preprocess, 121.4ms inference, 9.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 4 cars, 1 motorcycle, 1 truck, 1 bed, 10.9ms
# Speed: 5.1ms preprocess, 10.9ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 3 cars, 1 motorcycle, 1 bed, 11.4ms
# Speed: 5.2ms preprocess, 11.4ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 3 motorcycles, 1 bed, 12.7ms
# Speed: 4.9ms preprocess, 12.7ms inference, 9.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 3 motorcycles, 1 truck, 1 bed, 12.5ms
# Speed: 4.2ms preprocess, 12.5ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 3 motorcycles, 1 bed, 12.9ms
# Speed: 3.9ms preprocess, 12.9ms inference, 8.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 3 motorcycles, 1 bed, 10.5ms
# Speed: 5.0ms preprocess, 10.5ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 3 motorcycles, 1 bed, 10.8ms
# Speed: 4.0ms preprocess, 10.8ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 3 cars, 3 motorcycles, 1 bed, 10.6ms
# Speed: 4.0ms preprocess, 10.6ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 persons, 4 cars, 3 motorcycles, 1 truck, 1 bed, 11.8ms
# Speed: 4.4ms preprocess, 11.8ms inference, 11.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 persons, 4 cars, 3 motorcycles, 1 truck, 1 bed, 11.8ms
# Speed: 4.1ms preprocess, 11.8ms inference, 11.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 4 motorcycles, 1 truck, 1 bed, 10.8ms
# Speed: 4.0ms preprocess, 10.8ms inference, 9.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 4 motorcycles, 1 truck, 1 bed, 11.6ms
# Speed: 3.8ms preprocess, 11.6ms inference, 8.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 2 cars, 5 motorcycles, 1 truck, 1 bed, 10.9ms
# Speed: 3.8ms preprocess, 10.9ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 4 cars, 4 motorcycles, 1 truck, 1 bed, 10.6ms
# Speed: 3.7ms preprocess, 10.6ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 5 motorcycles, 1 truck, 1 bed, 10.0ms
# Speed: 4.0ms preprocess, 10.0ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 2 cars, 4 motorcycles, 1 truck, 1 bed, 10.2ms
# Speed: 3.8ms preprocess, 10.2ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 2 cars, 5 motorcycles, 1 bed, 11.0ms
# Speed: 4.6ms preprocess, 11.0ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 2 cars, 6 motorcycles, 1 bed, 10.3ms
# Speed: 3.7ms preprocess, 10.3ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 6 motorcycles, 1 bed, 10.3ms
# Speed: 3.9ms preprocess, 10.3ms inference, 9.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 2 motorcycles, 1 truck, 1 bed, 10.3ms
# Speed: 3.9ms preprocess, 10.3ms inference, 7.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 2 trucks, 1 bed, 10.6ms
# Speed: 3.9ms preprocess, 10.6ms inference, 7.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 2 trucks, 10.4ms
# Speed: 3.9ms preprocess, 10.4ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 3 motorcycles, 1 truck, 11.4ms
# Speed: 3.8ms preprocess, 11.4ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 3 motorcycles, 1 truck, 11.4ms
# Speed: 4.1ms preprocess, 11.4ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 motorcycle, 1 truck, 10.9ms
# Speed: 3.9ms preprocess, 10.9ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 2 motorcycles, 1 truck, 11.1ms
# Speed: 4.1ms preprocess, 11.1ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 2 motorcycles, 1 truck, 11.4ms
# Speed: 4.1ms preprocess, 11.4ms inference, 7.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 4 motorcycles, 13.4ms
# Speed: 4.9ms preprocess, 13.4ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 4 motorcycles, 10.7ms
# Speed: 3.9ms preprocess, 10.7ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 2 motorcycles, 10.7ms
# Speed: 3.8ms preprocess, 10.7ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 2 motorcycles, 10.8ms
# Speed: 3.8ms preprocess, 10.8ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 3 motorcycles, 10.8ms
# Speed: 4.1ms preprocess, 10.8ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 3 motorcycles, 1 truck, 11.6ms
# Speed: 4.2ms preprocess, 11.6ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 3 motorcycles, 1 truck, 10.6ms
# Speed: 4.0ms preprocess, 10.6ms inference, 7.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 2 motorcycles, 1 truck, 11.4ms
# Speed: 3.8ms preprocess, 11.4ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 2 motorcycles, 1 truck, 11.3ms
# Speed: 3.8ms preprocess, 11.3ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 11.6ms
# Speed: 4.0ms preprocess, 11.6ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 11.3ms
# Speed: 3.6ms preprocess, 11.3ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 1 car, 1 motorcycle, 11.0ms
# Speed: 3.9ms preprocess, 11.0ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 1 car, 1 motorcycle, 1 truck, 11.2ms
# Speed: 3.9ms preprocess, 11.2ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 motorcycles, 1 truck, 10.8ms
# Speed: 3.7ms preprocess, 10.8ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 motorcycles, 2 trucks, 10.7ms
# Speed: 3.8ms preprocess, 10.7ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 motorcycle, 2 trucks, 11.4ms
# Speed: 3.8ms preprocess, 11.4ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 motorcycle, 2 trucks, 10.7ms
# Speed: 5.1ms preprocess, 10.7ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 motorcycle, 1 truck, 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 motorcycle, 2 trucks, 11.7ms
# Speed: 4.3ms preprocess, 11.7ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 motorcycle, 2 trucks, 10.7ms
# Speed: 3.9ms preprocess, 10.7ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 motorcycle, 1 truck, 1 bed, 10.5ms
# Speed: 3.9ms preprocess, 10.5ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 512)
# DANGER DETECTED! Triggering voice alert.
#
# 0: 640x512 1 person, 2 cars, 1 motorcycle, 1 truck, 1 bed, 12.1ms
# Speed: 4.2ms preprocess, 12.1ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 1 car, 1 motorcycle, 1 truck, 1 bed, 11.3ms
# Speed: 4.1ms preprocess, 11.3ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 10.9ms
# Speed: 4.1ms preprocess, 10.9ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 2 trucks, 10.4ms
# Speed: 3.8ms preprocess, 10.4ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 10.7ms
# Speed: 3.8ms preprocess, 10.7ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 1 car, 2 motorcycles, 1 truck, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 1 car, 1 motorcycle, 1 truck, 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 1 car, 2 motorcycles, 1 truck, 1 bed, 10.7ms
# Speed: 4.5ms preprocess, 10.7ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 1 car, 1 motorcycle, 1 bus, 1 truck, 1 bed, 14.3ms
# Speed: 4.2ms preprocess, 14.3ms inference, 7.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 bus, 1 truck, 1 bed, 11.0ms
# Speed: 6.5ms preprocess, 11.0ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 bus, 1 truck, 1 bed, 10.3ms
# Speed: 3.8ms preprocess, 10.3ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 bus, 1 truck, 1 bed, 9.9ms
# Speed: 3.6ms preprocess, 9.9ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 1 car, 1 motorcycle, 1 bus, 1 truck, 1 bed, 9.9ms
# Speed: 3.6ms preprocess, 9.9ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 1 car, 1 motorcycle, 1 bus, 1 truck, 1 bed, 9.5ms
# Speed: 3.6ms preprocess, 9.5ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 10.5ms
# Speed: 3.7ms preprocess, 10.5ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 12.9ms
# Speed: 4.2ms preprocess, 12.9ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 12.0ms
# Speed: 4.4ms preprocess, 12.0ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 11.7ms
# Speed: 4.2ms preprocess, 11.7ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 11.9ms
# Speed: 4.2ms preprocess, 11.9ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 10.2ms
# Speed: 4.0ms preprocess, 10.2ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 10.1ms
# Speed: 3.9ms preprocess, 10.1ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 10.4ms
# Speed: 3.8ms preprocess, 10.4ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 10.2ms
# Speed: 4.4ms preprocess, 10.2ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 10.8ms
# Speed: 3.9ms preprocess, 10.8ms inference, 6.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 11.4ms
# Speed: 3.9ms preprocess, 11.4ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 10.5ms
# Speed: 4.4ms preprocess, 10.5ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 10.3ms
# Speed: 3.7ms preprocess, 10.3ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 1 truck, 1 bed, 10.7ms
# Speed: 4.3ms preprocess, 10.7ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 motorcycle, 2 trucks, 1 bed, 10.9ms
# Speed: 3.8ms preprocess, 10.9ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 motorcycle, 2 trucks, 1 bed, 10.4ms
# Speed: 4.0ms preprocess, 10.4ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 512)
# DANGER DETECTED! Triggering voice alert.
#
# 0: 640x512 2 cars, 2 trucks, 11.3ms
# Speed: 4.5ms preprocess, 11.3ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 11.0ms
# Speed: 4.3ms preprocess, 11.0ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.0ms
# Speed: 4.8ms preprocess, 11.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 4 trucks, 11.2ms
# Speed: 4.0ms preprocess, 11.2ms inference, 7.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 2 trucks, 10.8ms
# Speed: 4.1ms preprocess, 10.8ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 motorcycle, 2 trucks, 13.1ms
# Speed: 4.2ms preprocess, 13.1ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 motorcycle, 2 trucks, 10.7ms
# Speed: 4.0ms preprocess, 10.7ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 13.9ms
# Speed: 4.3ms preprocess, 13.9ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 2 trucks, 12.2ms
# Speed: 4.8ms preprocess, 12.2ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 motorcycle, 2 trucks, 11.1ms
# Speed: 3.8ms preprocess, 11.1ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 3 trucks, 11.2ms
# Speed: 3.9ms preprocess, 11.2ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 2 trucks, 10.8ms
# Speed: 4.0ms preprocess, 10.8ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 2 trucks, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 truck, 11.2ms
# Speed: 4.1ms preprocess, 11.2ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 truck, 11.2ms
# Speed: 3.7ms preprocess, 11.2ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.5ms
# Speed: 3.6ms preprocess, 11.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 9.8ms
# Speed: 3.6ms preprocess, 9.8ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 2 trucks, 9.8ms
# Speed: 4.0ms preprocess, 9.8ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 10.1ms
# Speed: 3.8ms preprocess, 10.1ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 2 trucks, 10.2ms
# Speed: 4.0ms preprocess, 10.2ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 2 trucks, 10.0ms
# Speed: 3.7ms preprocess, 10.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.2ms
# Speed: 3.9ms preprocess, 10.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.2ms
# Speed: 3.9ms preprocess, 10.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.2ms
# Speed: 4.4ms preprocess, 10.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 10.1ms
# Speed: 3.8ms preprocess, 10.1ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 10.0ms
# Speed: 3.9ms preprocess, 10.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.2ms
# Speed: 4.6ms preprocess, 10.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 10.1ms
# Speed: 3.6ms preprocess, 10.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 10.5ms
# Speed: 3.9ms preprocess, 10.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.1ms
# Speed: 5.9ms preprocess, 11.1ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 2 trucks, 11.3ms
# Speed: 4.2ms preprocess, 11.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 11.5ms
# Speed: 4.4ms preprocess, 11.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 10.9ms
# Speed: 4.1ms preprocess, 10.9ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 1 mouse, 10.9ms
# Speed: 4.3ms preprocess, 10.9ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 1 mouse, 12.0ms
# Speed: 3.7ms preprocess, 12.0ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 11.4ms
# Speed: 4.4ms preprocess, 11.4ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 14.1ms
# Speed: 4.0ms preprocess, 14.1ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 13.5ms
# Speed: 4.0ms preprocess, 13.5ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 14.2ms
# Speed: 4.0ms preprocess, 14.2ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 13.9ms
# Speed: 4.8ms preprocess, 13.9ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 2 trucks, 17.7ms
# Speed: 4.4ms preprocess, 17.7ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 14.3ms
# Speed: 5.7ms preprocess, 14.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 3 trucks, 10.7ms
# Speed: 3.7ms preprocess, 10.7ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 2 trucks, 10.9ms
# Speed: 4.6ms preprocess, 10.9ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 3 trucks, 10.6ms
# Speed: 3.7ms preprocess, 10.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 3 trucks, 10.6ms
# Speed: 3.7ms preprocess, 10.6ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 3 trucks, 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 10.6ms
# Speed: 3.9ms preprocess, 10.6ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 10.3ms
# Speed: 3.8ms preprocess, 10.3ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 2 trucks, 11.3ms
# Speed: 4.2ms preprocess, 11.3ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 15.4ms
# Speed: 6.0ms preprocess, 15.4ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 13.5ms
# Speed: 4.1ms preprocess, 13.5ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.6ms
# Speed: 4.5ms preprocess, 11.6ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 11.7ms
# Speed: 4.3ms preprocess, 11.7ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 10.0ms
# Speed: 4.4ms preprocess, 10.0ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 10.0ms
# Speed: 3.6ms preprocess, 10.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 9.8ms
# Speed: 3.8ms preprocess, 9.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 13.6ms
# Speed: 5.5ms preprocess, 13.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 10.7ms
# Speed: 5.7ms preprocess, 10.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 14.0ms
# Speed: 6.4ms preprocess, 14.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 15.1ms
# Speed: 5.8ms preprocess, 15.1ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 10.0ms
# Speed: 3.7ms preprocess, 10.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 9.6ms
# Speed: 3.6ms preprocess, 9.6ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.1ms
# Speed: 3.8ms preprocess, 10.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.2ms
# Speed: 3.6ms preprocess, 10.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.2ms
# Speed: 3.8ms preprocess, 10.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 12.9ms
# Speed: 4.2ms preprocess, 12.9ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 14.1ms
# Speed: 4.2ms preprocess, 14.1ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 13.1ms
# Speed: 4.4ms preprocess, 13.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 12.9ms
# Speed: 4.9ms preprocess, 12.9ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 14.1ms
# Speed: 3.9ms preprocess, 14.1ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 13.5ms
# Speed: 4.1ms preprocess, 13.5ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 13.4ms
# Speed: 4.3ms preprocess, 13.4ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 10.8ms
# Speed: 4.1ms preprocess, 10.8ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 13.6ms
# Speed: 4.0ms preprocess, 13.6ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 13.3ms
# Speed: 3.8ms preprocess, 13.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 12.8ms
# Speed: 3.8ms preprocess, 12.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.4ms
# Speed: 3.8ms preprocess, 10.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.1ms
# Speed: 3.7ms preprocess, 10.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.4ms
# Speed: 3.6ms preprocess, 10.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.3ms
# Speed: 4.3ms preprocess, 10.3ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.4ms
# Speed: 3.7ms preprocess, 10.4ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.2ms
# Speed: 3.9ms preprocess, 10.2ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.4ms
# Speed: 3.9ms preprocess, 10.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.2ms
# Speed: 3.8ms preprocess, 10.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 train, 10.5ms
# Speed: 3.8ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 train, 10.3ms
# Speed: 3.8ms preprocess, 10.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 train, 10.5ms
# Speed: 3.9ms preprocess, 10.5ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 15.2ms
# Speed: 3.7ms preprocess, 15.2ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 11.7ms
# Speed: 3.6ms preprocess, 11.7ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 11.3ms
# Speed: 4.2ms preprocess, 11.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 11.3ms
# Speed: 4.0ms preprocess, 11.3ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 512)
# DANGER DETECTED! Triggering voice alert.
#
# 0: 640x512 3 cars, 11.2ms
# Speed: 3.9ms preprocess, 11.2ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 11.4ms
# Speed: 3.8ms preprocess, 11.4ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.1ms
# Speed: 3.8ms preprocess, 11.1ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 15.8ms
# Speed: 6.0ms preprocess, 15.8ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 9.8ms
# Speed: 3.7ms preprocess, 9.8ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 truck, 10.0ms
# Speed: 3.7ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 10.0ms
# Speed: 3.7ms preprocess, 10.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 9.9ms
# Speed: 3.8ms preprocess, 9.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 10.2ms
# Speed: 3.6ms preprocess, 10.2ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 10.7ms
# Speed: 4.0ms preprocess, 10.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 10.6ms
# Speed: 3.8ms preprocess, 10.6ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 14.1ms
# Speed: 4.0ms preprocess, 14.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 14.6ms
# Speed: 5.1ms preprocess, 14.6ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 11.9ms
# Speed: 4.3ms preprocess, 11.9ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 11.0ms
# Speed: 5.1ms preprocess, 11.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 11.9ms
# Speed: 4.0ms preprocess, 11.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 12.0ms
# Speed: 4.9ms preprocess, 12.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 12.3ms
# Speed: 4.0ms preprocess, 12.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.5ms
# Speed: 4.8ms preprocess, 11.5ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 12.0ms
# Speed: 4.1ms preprocess, 12.0ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 11.8ms
# Speed: 3.9ms preprocess, 11.8ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 16.3ms
# Speed: 6.2ms preprocess, 16.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 12.8ms
# Speed: 5.7ms preprocess, 12.8ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 11.1ms
# Speed: 4.0ms preprocess, 11.1ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 11.2ms
# Speed: 4.1ms preprocess, 11.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 10.9ms
# Speed: 4.7ms preprocess, 10.9ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 11.6ms
# Speed: 5.3ms preprocess, 11.6ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 11.7ms
# Speed: 3.9ms preprocess, 11.7ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 12.3ms
# Speed: 4.0ms preprocess, 12.3ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 12.0ms
# Speed: 4.3ms preprocess, 12.0ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 11.3ms
# Speed: 4.9ms preprocess, 11.3ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.2ms
# Speed: 4.4ms preprocess, 11.2ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 2 trucks, 11.2ms
# Speed: 5.8ms preprocess, 11.2ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.4ms
# Speed: 3.8ms preprocess, 11.4ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 10.9ms
# Speed: 3.9ms preprocess, 10.9ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 10.8ms
# Speed: 3.9ms preprocess, 10.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 10.7ms
# Speed: 3.7ms preprocess, 10.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 10.9ms
# Speed: 4.5ms preprocess, 10.9ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 11.5ms
# Speed: 3.9ms preprocess, 11.5ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 trucks, 11.5ms
# Speed: 3.8ms preprocess, 11.5ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 truck, 11.3ms
# Speed: 3.8ms preprocess, 11.3ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 2 trucks, 11.3ms
# Speed: 3.8ms preprocess, 11.3ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 1 car, 2 trucks, 11.4ms
# Speed: 3.8ms preprocess, 11.4ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 persons, 3 cars, 2 trucks, 11.5ms
# Speed: 4.0ms preprocess, 11.5ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 truck, 11.3ms
# Speed: 4.0ms preprocess, 11.3ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 1 truck, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 7.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 2 trucks, 11.6ms
# Speed: 4.0ms preprocess, 11.6ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.3ms
# Speed: 3.8ms preprocess, 11.3ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 11.2ms
# Speed: 4.0ms preprocess, 11.2ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 11.3ms
# Speed: 4.1ms preprocess, 11.3ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 11.8ms
# Speed: 4.2ms preprocess, 11.8ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 10.8ms
# Speed: 4.8ms preprocess, 10.8ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 10.9ms
# Speed: 3.8ms preprocess, 10.9ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 11.6ms
# Speed: 3.8ms preprocess, 11.6ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 trucks, 11.2ms
# Speed: 3.9ms preprocess, 11.2ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 12.9ms
# Speed: 3.8ms preprocess, 12.9ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 10.6ms
# Speed: 4.0ms preprocess, 10.6ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 car, 1 truck, 11.0ms
# Speed: 4.0ms preprocess, 11.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 1 truck, 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 2 trucks, 10.8ms
# Speed: 4.0ms preprocess, 10.8ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 cars, 10.6ms
# Speed: 3.8ms preprocess, 10.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 motorcycle, 1 truck, 10.7ms
# Speed: 3.8ms preprocess, 10.7ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 truck, 10.0ms
# Speed: 3.7ms preprocess, 10.0ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 truck, 10.6ms
# Speed: 3.6ms preprocess, 10.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 4 cars, 1 truck, 9.9ms
# Speed: 4.3ms preprocess, 9.9ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 1 motorcycle, 10.3ms
# Speed: 3.7ms preprocess, 10.3ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 1 truck, 10.0ms
# Speed: 3.6ms preprocess, 10.0ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 9.8ms
# Speed: 3.7ms preprocess, 9.8ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 10.3ms
# Speed: 4.1ms preprocess, 10.3ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 2 cars, 1 truck, 11.6ms
# Speed: 4.2ms preprocess, 11.6ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 2 trucks, 12.5ms
# Speed: 4.1ms preprocess, 12.5ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 truck, 14.0ms
# Speed: 5.3ms preprocess, 14.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 truck, 12.3ms
# Speed: 4.2ms preprocess, 12.3ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 3 cars, 1 truck, 11.2ms
# Speed: 4.8ms preprocess, 11.2ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 1 truck, 12.3ms
# Speed: 4.8ms preprocess, 12.3ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 4 cars, 1 truck, 14.1ms
# Speed: 4.4ms preprocess, 14.1ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 5 cars, 2 motorcycles, 1 truck, 14.2ms
# Speed: 5.7ms preprocess, 14.2ms inference, 10.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 truck, 11.0ms
# Speed: 4.1ms preprocess, 11.0ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 1 truck, 11.1ms
# Speed: 3.9ms preprocess, 11.1ms inference, 6.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 2 persons, 3 cars, 1 airplane, 1 truck, 9.9ms
# Speed: 3.9ms preprocess, 9.9ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 1 person, 3 cars, 1 motorcycle, 1 truck, 10.3ms
# Speed: 3.8ms preprocess, 10.3ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 512)
# Video finished or failed to read a frame.

# %%
print("Cleaning up resources...")
cap.release()
cv2.destroyAllWindows()
print("Script finished.")
# Out:
# Cleaning up resources...
# Script finished.

# %%
# import pyttsx3

# print("Initializing TTS engine...")
# try:
#     engine = pyttsx3.init()
# except Exception as e:
#     print(f"Error initializing engine: {e}")
#     exit()

# print("Engine initialized.")

# engine.setProperty('rate', 150)  # Speed of speech
# engine.setProperty('volume', 1.0) 

# print("Attempting to speak...")
# engine.say("Hello, this is a sound test. Can you hear me?")

# try:
#     engine.runAndWait()
#     print("Speech finished.")
# except Exception as e:
#     print(f"Error during runAndWait: {e}")

# print("Test complete.")
